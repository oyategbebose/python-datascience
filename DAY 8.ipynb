# %%
basic = int(input('Enter basic: ')
# Out:
#   File "<ipython-input-1-e9624442a680>", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
def intro():
    print('Earlycode company ')
    employee_name = input('employee name: ')
    Level = int(input('Enter employee level: ')) 
def current_payment():
    basic = int(input('Basic salary: '))
    HA = basic * 0.15
    LA = basic * 0.25
    TA = basic * 0.15
    TRA = basic * 0.35
    MA = basic * 0.20
    PF = basic * 0.15
    NETPAY = HA + LA + TA + TRA + MA + basic
    GROSSPAY = NETPAY - PF
    print (f'''Basic salary:{basic}
HOUSING ALLOWANCE:{HA}
LEAVE ALLOWANCE:{LA}
TRANSPORT ALLOWANCE:{TA}
TRAVEL ALLOWANCE:{TRA}
MEDICAL ALLOWANCE:{MA}
PROVIDENT ALLOWANCE:{PF}
NETPAY:{NETPAY}
GROSSPAY:{GROSSPAY} 
''')
def update_payment_level1():
    basic = int(input('Basic salary'))
    Ubasic = (basic * 0.05) + basic 
    UHA = Ubasic * 0.15
    ULA = Ubasic * 0.25
    UTA = Ubasic * 0.15
    UTRA = Ubasic * 0.35
    UMA = Ubasic * 0.20
    UPF = Ubasic * 0.15
    UNETPAY = UHA + ULA + UTA + UTRA + UMA + Ubasic
    UGROSSPAY = UNETPAY - UPF
    print (f'''Basic salary:{Ubasic}
HOUSING ALLOWANCE:{UHA}
LEAVE ALLOWANCE:{ULA}
TRANSPORT ALLOWANCE:{UTA}
TRAVEL ALLOWANCE:{UTRA}
MEDICAL ALLOWANCE:{UMA}
PROVIDENT ALLOWANCE:{UPF}
NETPAY:{UNETPAY}
GROSSPAY:{UGROSSPAY} 
''')
def update_payment_level2():
    basic = int(input('Basic salary'))
    Ubasic = (basic * 0.10) + basic 
    UHA = Ubasic * 0.15
    ULA = Ubasic * 0.25
    UTA = Ubasic * 0.15
    UTRA = Ubasic * 0.35
    UMA = Ubasic * 0.20
    UPF = Ubasic * 0.15
    UNETPAY = UHA + ULA + UTA + UTRA + UMA + Ubasic
    UGROSSPAY = UNETPAY - UPF
    print (f'''Basic salary:{Ubasic}
HOUSING ALLOWANCE:{UHA}
LEAVE ALLOWANCE:{ULA}
TRANSPORT ALLOWANCE:{UTA}
TRAVEL ALLOWANCE:{UTRA}
MEDICAL ALLOWANCE:{UMA}
PROVIDENT ALLOWANCE:{UPF}
NETPAY:{UNETPAY}
GROSSPAY:{UGROSSPAY} 
''')
def update_payment_level3():
    basic = int(input('Basic salary'))
    Ubasic = (basic * 0.15) + basic 
    UHA = Ubasic * 0.15
    ULA = Ubasic * 0.25
    UTA = Ubasic * 0.15
    UTRA = Ubasic * 0.35
    UMA = Ubasic * 0.20
    UPF = Ubasic * 0.15
    UNETPAY = UHA + ULA + UTA + UTRA + UMA + Ubasic
    UGROSSPAY = UNETPAY - UPF
    print (f'''Basic salary:{Ubasic}
HOUSING ALLOWANCE:{UHA}
LEAVE ALLOWANCE:{ULA}
TRANSPORT ALLOWANCE:{UTA}
TRAVEL ALLOWANCE:{UTRA}
MEDICAL ALLOWANCE:{UMA}
PROVIDENT ALLOWANCE:{UPF}
NETPAY:{UNETPAY}
GROSSPAY:{UGROSSPAY} 
''')
def update_payment_level4():
    basic = int(input('Basic salary'))
    Ubasic = (basic * 0.20) + basic 
    UHA = Ubasic * 0.15
    ULA = Ubasic * 0.25
    UTA = Ubasic * 0.15
    UTRA = Ubasic * 0.35
    UMA = Ubasic * 0.20
    UPF = Ubasic * 0.15
    UNETPAY = UHA + ULA + UTA + UTRA + UMA + Ubasic
    UGROSSPAY = UNETPAY - UPF
    print (f'''Basic salary:{Ubasic}
HOUSING ALLOWANCE:{UHA}
LEAVE ALLOWANCE:{ULA}
TRANSPORT ALLOWANCE:{UTA}
TRAVEL ALLOWANCE:{UTRA}
MEDICAL ALLOWANCE:{UMA}
PROVIDENT ALLOWANCE:{UPF}
NETPAY:{UNETPAY}
GROSSPAY:{UGROSSPAY} 
''')
def update_payment_others_level():
    basic = int(input('Basic salary'))
    Ubasic = (basic * 0.25) + basic 
    UHA = Ubasic * 0.15
    ULA = Ubasic * 0.25
    UTA = Ubasic * 0.15
    UTRA = Ubasic * 0.35
    UMA = Ubasic * 0.20
    UPF = Ubasic * 0.15
    UNETPAY = UHA + ULA + UTA + UTRA + UMA + Ubasic
    UGROSSPAY = UNETPAY - UPF
    print (f'''Basic salary:{Ubasic}
HOUSING ALLOWANCE:{UHA}
LEAVE ALLOWANCE:{ULA}
TRANSPORT ALLOWANCE:{UTA}
TRAVEL ALLOWANCE:{UTRA}
MEDICAL ALLOWANCE:{UMA}
PROVIDENT ALLOWANCE:{UPF}
NETPAY:{UNETPAY}
GROSSPAY:{UGROSSPAY} 
''')

# %%
intro()
current_payment()
update_payment_level1()
update_payment_level2()
update_payment_level3()
update_payment_level4()
update_payment_others_level()
# Out:
# Earlycode company
# employee name: Ade Jones
# Enter employee level: 1
# Basic salary: 24000
# Basic salary:24000
# HOUSING ALLOWANCE:3600.0
# LEAVE ALLOWANCE:6000.0
# TRANSPORT ALLOWANCE:3600.0
# TRAVEL ALLOWANCE:8400.0
# MEDICAL ALLOWANCE:4800.0
# PROVIDENT ALLOWANCE:3600.0
# NETPAY:50400.0
# GROSSPAY:46800.0
#
# Basic salary24000
# Basic salary:25200.0
# HOUSING ALLOWANCE:3780.0
# LEAVE ALLOWANCE:6300.0
# TRANSPORT ALLOWANCE:3780.0
# TRAVEL ALLOWANCE:8820.0
# MEDICAL ALLOWANCE:5040.0
# PROVIDENT ALLOWANCE:3780.0
# NETPAY:52920.0
# GROSSPAY:49140.0
#
# Basic salary24000
# Basic salary:26400.0
# HOUSING ALLOWANCE:3960.0
# LEAVE ALLOWANCE:6600.0
# TRANSPORT ALLOWANCE:3960.0
# TRAVEL ALLOWANCE:9240.0
# MEDICAL ALLOWANCE:5280.0
# PROVIDENT ALLOWANCE:3960.0
# NETPAY:55440.0
# GROSSPAY:51480.0
#
# Basic salary24000
# Basic salary:27600.0
# HOUSING ALLOWANCE:4140.0
# LEAVE ALLOWANCE:6900.0
# TRANSPORT ALLOWANCE:4140.0
# TRAVEL ALLOWANCE:9660.0
# MEDICAL ALLOWANCE:5520.0
# ...
